# %% [markdown]
# <a href="https://colab.research.google.com/github/rj05-ux/customer-segmentation-rfm/blob/main/notebooks/02_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
#
# ## Objective
#
# To understand patterns in customer transactions and identify key trends in the dataset.
#
# ## Key Questions
#
# * Which countries generate the most revenue?
# * What are the monthly sales trends?
# * Who are the top customers?
#
# ## Analysis Performed
#
# * Revenue distribution
# * Top countries by sales
# * Monthly revenue trends
# * Customer spending analysis
#
# ## Outcome
#
# Insights into customer behavior and business performance.
